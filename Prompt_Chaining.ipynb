# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
class BlogState(TypedDict):
    topic: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state['topic']

    prompt = f'generate a detailed outline for a blog of this topic - {title}'
    outline = model.invoke(prompt).content

    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:
    title = state['topic']
    outline = state['outline']

    prompt = f'generate a blog of this topic - {title} using this outline - {outline}'
    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# %%
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)  

workflow = graph.compile()
# Out:
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.

# %%
initial_stage = {'topic':'The Rise of Pakistan'}
final_stage = workflow.invoke(initial_stage)

print(final_stage['outline'])
# Out:
# Here's a detailed outline for a blog post on "The Rise of Pakistan," designed to be engaging, informative, and accessible to a general audience.
#
# ---
#
# ## Blog Title Options:
#
# *   **From Vision to Nation: The Epic Rise of Pakistan**
# *   **A Nation Forged in Fire: Tracing the Rise of Pakistan**
# *   **The Genesis of Pakistan: How an Idea Became a Country**
# *   **Beyond Partition: Understanding the Complex Rise of Pakistan**
#
# ---
#
# ## Detailed Blog Outline: The Rise of Pakistan
#
# ### I. Introduction (Approx. 150-200 words)
#
# *   **A. Catchy Hook:**
#     *   Start with a provocative question: "Imagine a nation born out of an idea, carved from an ancient land, and brought into existence against incredible odds. That nation is Pakistan."
#     *   Or, a striking statement: "On August 14, 1947, a new star appeared on the world map, representing a dream turned into reality for millions of Muslims in British India: Pakistan."
# *   **B. Brief Context Setting:**
# ...

# %%
print(final_stage['content'])
# Out:
# **From Vision to Nation: The Epic Rise of Pakistan**
#
# ...
